# %% [markdown]
# # Discrete Anomaly Detection

# %% [markdown]
# ## Imports

# %%
from __future__ import division
import itertools
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import pandas as pd
import math
from sklearn import metrics
from random import randint
from matplotlib import style
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### 1. Discrete Data + Probability:
# * Use basic probability to identify anomalous request methods. You will want to make sure the text is normalized in order to reduce the noise.

# %% [markdown]
# ### Wrangle Data

# %% [markdown]
# #### Acquire

# %%
colnames=['ip', 'timestamp', 'request_method', 'status', 'size',
          'destination', 'request_agent']
df_orig = pd.read_csv('http://python.zach.lol/access.log',          
                 engine='python',
                 header=None,
                 index_col=False,
                 names=colnames,
                 sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',
                 na_values='"-"',
                 usecols=[0, 3, 4, 5, 6, 7, 8]
)

new = pd.DataFrame([["95.31.18.119", "[21/Apr/2019:10:02:41+0000]", 
                     "GET /api/v1/items/HTTP/1.1", 200, 1153005, np.nan, 
                     "python-requests/2.21.0"],
                    ["95.31.16.121", "[17/Apr/2019:19:36:41+0000]", 
                     "GET /api/v1/sales?page=79/HTTP/1.1", 301, 1005, np.nan, 
                     "python-requests/2.21.0"],
                    ["97.105.15.120", "[18/Apr/2019:19:42:41+0000]", 
                     "GET /api/v1/sales?page=79/HTTP/1.1", 301, 2560, np.nan, 
                     "python-requests/2.21.0"],
                    ["97.105.19.58", "[19/Apr/2019:19:42:41+0000]", 
                     "GET /api/v1/sales?page=79/HTTP/1.1", 200, 2056327, np.nan, 
                     "python-requests/2.21.0"]], columns=colnames)

df = df_orig.append(new)

# %%
df.head()
# Out:
#              ip                     timestamp  \
# 0  97.105.19.58  [16/Apr/2019:19:34:42 +0000]
# 1  97.105.19.58  [16/Apr/2019:19:34:42 +0000]
# 2  97.105.19.58  [16/Apr/2019:19:34:44 +0000]
# 3  97.105.19.58  [16/Apr/2019:19:34:46 +0000]
# 4  97.105.19.58  [16/Apr/2019:19:34:48 +0000]
#
#                          request_method  status    size destination  \
# 0  "GET /api/v1/sales?page=81 HTTP/1.1"     200  512495         NaN
# 1          "GET /api/v1/items HTTP/1.1"     200    3561         NaN
# 2  "GET /api/v1/sales?page=82 HTTP/1.1"     200  510103         NaN
# 3  "GET /api/v1/sales?page=83 HTTP/1.1"     200  510003         NaN
# 4  "GET /api/v1/sales?page=84 HTTP/1.1"     200  511963         NaN
#
#               request_agent
# 0  "python-requests/2.21.0"
# 1  "python-requests/2.21.0"
# 2  "python-requests/2.21.0"
# 3  "python-requests/2.21.0"
# 4  "python-requests/2.21.0"

# %%
#column and datatype summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13978 entries, 0 to 3
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ip              13978 non-null  object
#  1   timestamp       13978 non-null  object
#  2   request_method  13978 non-null  object
#  3   status          13978 non-null  int64
#  4   size            13978 non-null  int64
#  5   destination     25 non-null     object
#  6   request_agent   13978 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 873.6+ KB

# %%
# begin cleaning up the timestamp by removing the brackets and extraneous tail

df.timestamp = df.timestamp.str.replace(r'(\[|\+0000\])', '', regex=True)

# %%
df.head(2)
# Out:
#              ip              timestamp                        request_method  \
# 0  97.105.19.58  16/Apr/2019:19:34:42   "GET /api/v1/sales?page=81 HTTP/1.1"
# 1  97.105.19.58  16/Apr/2019:19:34:42           "GET /api/v1/items HTTP/1.1"
#
#    status    size destination             request_agent
# 0     200  512495         NaN  "python-requests/2.21.0"
# 1     200    3561         NaN  "python-requests/2.21.0"

# %%
# replace the first colon in the timestamp before year 
# to accomodate for pandas datetime
df.timestamp= pd.to_datetime(df.timestamp.str.replace(':', ' ', 1))
# reset index to time
df = df.set_index('timestamp')

# %%
df.head(2)
# Out:
#                                ip                        request_method  \
# timestamp
# 2019-04-16 19:34:42  97.105.19.58  "GET /api/v1/sales?page=81 HTTP/1.1"
# 2019-04-16 19:34:42  97.105.19.58          "GET /api/v1/items HTTP/1.1"
#
#                      status    size destination             request_agent
# timestamp
# 2019-04-16 19:34:42     200  512495         NaN  "python-requests/2.21.0"
# 2019-04-16 19:34:42     200    3561         NaN  "python-requests/2.21.0"

# %%
# clean up strings in columns with extra quotes
for col in ['request_method', 'request_agent', 'destination']:
    df[col] = df[col].str.replace('"', '')

# simplify and clean up request method by removing page data
df['request_method'] = df.request_method.str.replace(r'\?page=[0-9]+', '', regex=True)

df.head()
# Out:
#                                ip              request_method  status    size  \
# timestamp
# 2019-04-16 19:34:42  97.105.19.58  GET /api/v1/sales HTTP/1.1     200  512495
# 2019-04-16 19:34:42  97.105.19.58  GET /api/v1/items HTTP/1.1     200    3561
# 2019-04-16 19:34:44  97.105.19.58  GET /api/v1/sales HTTP/1.1     200  510103
# 2019-04-16 19:34:46  97.105.19.58  GET /api/v1/sales HTTP/1.1     200  510003
# 2019-04-16 19:34:48  97.105.19.58  GET /api/v1/sales HTTP/1.1     200  511963
#
#                     destination           request_agent
# timestamp
# 2019-04-16 19:34:42         NaN  python-requests/2.21.0
# 2019-04-16 19:34:42         NaN  python-requests/2.21.0
# 2019-04-16 19:34:44         NaN  python-requests/2.21.0
# 2019-04-16 19:34:46         NaN  python-requests/2.21.0
# 2019-04-16 19:34:48         NaN  python-requests/2.21.0

# %%
#Add Variable - Converting bytes to mb:

df['size_mb'] = [n/1024/1024 for n in df['size']]

# %%
df.head(2)
# Out:
#                                ip              request_method  status    size  \
# timestamp
# 2019-04-16 19:34:42  97.105.19.58  GET /api/v1/sales HTTP/1.1     200  512495
# 2019-04-16 19:34:42  97.105.19.58  GET /api/v1/items HTTP/1.1     200    3561
#
#                     destination           request_agent   size_mb
# timestamp
# 2019-04-16 19:34:42         NaN  python-requests/2.21.0  0.488753
# 2019-04-16 19:34:42         NaN  python-requests/2.21.0  0.003396

# %%
df.describe()
# Out:
#              status          size       size_mb
# count  13978.000000  1.397800e+04  13978.000000
# mean     200.356703  4.500019e+05      0.429155
# std       10.182001  1.614915e+05      0.154010
# min      200.000000  0.000000e+00      0.000000
# 25%      200.000000  5.006370e+05      0.477445
# 50%      200.000000  5.101380e+05      0.486506
# 75%      200.000000  5.112910e+05      0.487605
# max      499.000000  2.056327e+06      1.961066

# %%
# get the counts of ips in the dataset
request_method_df = df.request_method.value_counts(dropna=False).reset_index().\
                rename(columns={'index': 'request_method', 'request_method': 'request_count'})

# %%
# get the probability of that ip in the dataset
request_method_df2 = (df.request_method.value_counts(dropna=False)/df.request_method.count()).reset_index().\
                rename(columns={'index': 'request_method', 'request_method': 'request_proba'})
# merge/join these together
request_method_df = request_method_df.merge(request_method_df2)

# %%
request_method_df.head()
# Out:
#                 request_method  request_count  request_proba
# 0   GET /api/v1/sales HTTP/1.1          12403       0.887323
# 1   GET /api/v1/items HTTP/1.1           1065       0.076191
# 2  GET /api/v1/stores HTTP/1.1            229       0.016383
# 3               GET / HTTP/1.1            107       0.007655
# 4  GET /documentation HTTP/1.1            100       0.007154

# %%
request_method_df.shape
# Out:
# (22, 3)

# %%
# alter the request df to only see those where rate < 1% 
request_method_df[request_method_df.request_proba < 0.01]
# Out:
#                                   request_method  request_count  request_proba
# 3                                 GET / HTTP/1.1            107       0.007655
# 4                    GET /documentation HTTP/1.1            100       0.007154
# 5                      GET /favicon.ico HTTP/1.1             26       0.001860
# 6             GET /api/v1//api/v1/items HTTP/1.1             11       0.000787
# 7        GET /api/v1/items/api/v1/items HTTP/1.1              7       0.000501
# 8           GET /api/v1/items/next_page HTTP/1.1              5       0.000358
# 9                          GET /api/v1/ HTTP/1.1              4       0.000286
# 10                   GET /api/v1/sales/ HTTP/1.1              3       0.000215
# 11                    GET /api/v1/sales/HTTP/1.1              3       0.000215
# 12                    GET /api/v1/store HTTP/1.1              3       0.000215
# 13               GET /api/v1/itemsitems HTTP/1.1              3       0.000215
# ...

# %%
print(len(request_method_df))

print(request_method_df.tail(10))

plt.figure(figsize=(12, 4))
splot = sns.barplot(data=request_method_df, x = 'request_method', y = 'request_count', ci = None)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', xytext = (0, 10), 
                   textcoords = 'offset points'
                   )
plt.xticks(rotation='vertical')
plt.show()
# Out:
# 22
#                                   request_method  request_count  request_proba
# 12                    GET /api/v1/store HTTP/1.1              3       0.000215
# 13               GET /api/v1/itemsitems HTTP/1.1              3       0.000215
# 14                     GET /api/v1items HTTP/1.1              2       0.000143
# 15        GET /api/v1/I_DIDNT_DO_IT!!!! HTTP/1.1              1       0.000072
# 16                  GET /api/V1/HiZach! HTTP/1.1              1       0.000072
# 17  GET /api/v1//api/v1/items/next_page HTTP/1.1              1       0.000072
# 18                    GET /api/v1/items/HTTP/1.1              1       0.000072
# 19             GET /api/v1/items&page=0 HTTP/1.1              1       0.000072
# 20              GET /api/v1/helloclass! HTTP/1.1              1       0.000072
# 21                          GET /api/v1 HTTP/1.1              1       0.000072

# %% [markdown]
# ### Detecting anomalies by establishing a baseline and evaluate as new data arrives.¶

# %% [markdown]
# #### Establish Baseline:

# %%
# create a training set
train = df.loc['2019-04-16 19:34:42':'2019-04-17 12:55:14']

# %%
train.size /df.size
# Out:
# 0.9997138360280441

# %%
train = train[['ip','request_method','status','size','destination','request_agent','size_mb']]

# %% [markdown]
# #### Compute probabilities based on train sample:

# %%
ip_df = pd.DataFrame(train.request_method.value_counts(dropna=False)/train.request_method.count()).reset_index().rename(columns={'index': 'request_method', 'request_method': 'request_proba'})

# %% [markdown]
# #### Merge probabilities with all data (train + new data):¶
# * Where the IP address is new, i.e. not seen in the training dataset, fill the probability with a value of 0.

# %%
df = df.reset_index().merge(request_method_df, on=['request_method'], how='left').fillna(value=0).set_index('timestamp')

# %%
# value counts?
df[df['request_proba'] == 0]
# Out:
# Empty DataFrame
# Columns: [ip, request_method, status, size, destination, request_agent, size_mb, request_count, request_proba]
# Index: []

# %% [markdown]
# ### Conditional Probabilities: Probabilities using 2 discrete variables

# %% [markdown]
# #### Probability of Status given IP Address:¶
# If we are looking for an unexpected status (like authentication failure) from a known/common IP address.

# %%
# prob(A|B) = prob(A & B) / prob(B)

# %%
request_method_probs = train.groupby('request_method').size().div(len(train))

status_given_request_method = pd.DataFrame(train.groupby(['request_method', 'status']).size().div(len(train)).\
                              div(request_method_probs,
                                 axis=0,
                                 level='request_method').\
                              reset_index().\
                              rename(columns={0: 'proba_status_given_request_method'})
                              )

# %%
status_given_request_method
# Out:
#                                   request_method  status  \
# 0                                 GET / HTTP/1.1     200
# 1                   GET /api/V1/HiZach! HTTP/1.1     200
# 2                           GET /api/v1 HTTP/1.1     200
# 3                          GET /api/v1/ HTTP/1.1     200
# 4             GET /api/v1//api/v1/items HTTP/1.1     200
# 5   GET /api/v1//api/v1/items/next_page HTTP/1.1     200
# 6         GET /api/v1/I_DIDNT_DO_IT!!!! HTTP/1.1     200
# 7               GET /api/v1/helloclass! HTTP/1.1     200
# 8                     GET /api/v1/items HTTP/1.1     200
# 9                     GET /api/v1/items HTTP/1.1     499
# 10             GET /api/v1/items&page=0 HTTP/1.1     200
# 11       GET /api/v1/items/api/v1/items HTTP/1.1     200
# 12          GET /api/v1/items/next_page HTTP/1.1     200
# 13               GET /api/v1/itemsitems HTTP/1.1     200
# 14                    GET /api/v1/sales HTTP/1.1     200
# ...

# %%
request_status_count = pd.DataFrame(train.groupby(['request_method', 'status'])['ip'].\
                              count().reset_index().\
                              rename(columns={'request_method': 'request_status_count'}))


request_status = status_given_request_method.merge(request_status_count)

# %%
request_status
# Out:
#                  request_method  status  proba_status_given_request_method  \
# 0                GET / HTTP/1.1     200                           1.000000
# 1                GET / HTTP/1.1     200                           1.000000
# 2                GET / HTTP/1.1     200                           1.000000
# 3                GET / HTTP/1.1     200                           1.000000
# 4                GET / HTTP/1.1     200                           1.000000
# ..                          ...     ...                                ...
# 399   GET /favicon.ico HTTP/1.1     200                           1.000000
# 400  GET /api/v1/items HTTP/1.1     499                           0.003756
# 401  GET /api/v1/items HTTP/1.1     499                           0.003756
# 402  GET /api/v1/sales HTTP/1.1     499                           0.000968
# 403  GET /api/v1/sales HTTP/1.1     499                           0.000968
#
#                    request_status_count   ip
# ...

# %% [markdown]
# ### Add these probabilities to original events to detect anomalous events:¶

# %%
df = df.reset_index().merge(request_status, on=['request_method', 'status'], how='left').fillna(value=0).set_index('timestamp')

# %%
df.head()
# Out:
#                              ip_x              request_method  status    size  \
# timestamp
# 2019-04-16 19:34:42  97.105.19.58  GET /api/v1/sales HTTP/1.1     200  512495
# 2019-04-16 19:34:42  97.105.19.58  GET /api/v1/sales HTTP/1.1     200  512495
# 2019-04-16 19:34:42  97.105.19.58  GET /api/v1/sales HTTP/1.1     200  512495
# 2019-04-16 19:34:42  97.105.19.58  GET /api/v1/sales HTTP/1.1     200  512495
# 2019-04-16 19:34:42  97.105.19.58  GET /api/v1/sales HTTP/1.1     200  512495
#
#                     destination           request_agent   size_mb  \
# timestamp
# 2019-04-16 19:34:42           0  python-requests/2.21.0  0.488753
# 2019-04-16 19:34:42           0  python-requests/2.21.0  0.488753
# 2019-04-16 19:34:42           0  python-requests/2.21.0  0.488753
# 2019-04-16 19:34:42           0  python-requests/2.21.0  0.488753
# 2019-04-16 19:34:42           0  python-requests/2.21.0  0.488753
#
#                      request_count  request_proba  \
# timestamp
# ...

# %%
# scatter plot
plt.scatter(df.proba_status_given_request_method, df.request_proba)
plt.show()

# %%
df[(df['proba_status_given_request_method'] > 0.9) & (df['request_proba'] < 0.2)]
# Out:
#                              ip_x               request_method  status  size  \
# timestamp
# 2019-04-16 19:34:42  97.105.19.58   GET /api/v1/items HTTP/1.1     200  3561
# 2019-04-16 19:34:42  97.105.19.58   GET /api/v1/items HTTP/1.1     200  3561
# 2019-04-16 19:34:42  97.105.19.58   GET /api/v1/items HTTP/1.1     200  3561
# 2019-04-16 19:34:42  97.105.19.58   GET /api/v1/items HTTP/1.1     200  3561
# 2019-04-16 19:34:42  97.105.19.58   GET /api/v1/items HTTP/1.1     200  3561
# ...                           ...                          ...     ...   ...
# 2019-04-17 10:25:50  45.23.250.16  GET /api/v1/stores HTTP/1.1     200  1328
# 2019-04-17 10:25:50  45.23.250.16  GET /api/v1/stores HTTP/1.1     200  1328
# 2019-04-17 10:25:50  45.23.250.16  GET /api/v1/stores HTTP/1.1     200  1328
# 2019-04-17 10:25:50  45.23.250.16  GET /api/v1/stores HTTP/1.1     200  1328
# 2019-04-17 10:25:50  45.23.250.16  GET /api/v1/stores HTTP/1.1     200  1328
#
# ...
